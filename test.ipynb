# %%
import pytesseract
from PIL import Image 

image_path = "/home/manish/Desktop/projects/etfp/data/WhatsApp Image 2025-09-13 at 19.01.24 (1).jpeg"
img = Image.open(image_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720>

# %%
extract_text = pytesseract.image_to_string(img)
extract_text
# Out:
# 'NEVE ALIVUANTT Pe ee\n\nBAJAJ, TVS CREDIT, HDB, DMI FAINANCE, HDFC FAINCE\n\nHARDUAGAN,J SUB POST OFFCE SHOP.NO. 10. OPPOSIT\nHarduaganj - 202125, Uttar Pradesh State Code : 09\n\nMobile : 9058464066, 9759059257 Email : sharmasaurav316@gmail.com\nInvoice No. : 128 GSTIN : O9FAEPS1994A1ZH\nDate of Invoice : 01-04-2024 Place of Supply : Uttar Pradesh\nBilling Address - Shipping Address :\nWAISHNAVI ENTERPRISES VAISHNAVI ENTERPRISES\nHARDUAGAN! HARDUAGANJ\n\n202125 Uttar Pradesh, State Code 09 202125 Uttar Pradesh, State Code : 09\n(GST No. - O9FGPK3468A1ZK GST No. : OSFGPK3468A1ZK\n\nContact : E-mail\nHSN/SAC GsT%| arty]\n18.00 | 12,000.00 | pes\n\nJcamon 20.46 81256 aDison\n\n85171300 | of 2| 12,500.00] pes\n\n'

# %% [markdown]
# ---

# %%
import pytesseract
from PIL import Image 

image_path = "/home/manish/Desktop/projects/etfp/data/WhatsApp Image 2025-09-13 at 19.01.53.jpeg"
img = Image.open(image_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x705>

# %%
extract_text = pytesseract.image_to_string(img)
extract_text
# Out:
# 'Tax Invoice\n(SUPPLY MEANT FOR EXPORTISUPPLY To SEZ UNIT OR SEZ DEVELOPER FOR AUTHORISED OPERATIONS ON PAYMENT OF GST)\n\nNational Enterprises invoice No, (Dated\n/Bommanahali, Bangab 47 5.Jul 2017\nGSTINUIN: 29) zi Datvany Note IModerTerms of Payment\nState Name ; Kamataka, Code : 29 DNe1 3 Installments\nSuppers Re [Other Reference\na7\nBorer Buyers Order No ated\nSSH Enterprises - Dhaka /SR/199 1.Jul.2017\nDhanmondi, Dhaka Despatch Document Na Delivery Nofe Dae\npoci271 5.Jul 2017\nDespatcned through Destination\n‘Cargo Flight Dhaka\nBil of Laing ERR NB wotor VOnETE ND,\n12121 at. S.Jul.2017_|6e771111\n\n(Courity Bangladesh\n\nFromme o Delvey\niy Description of Goods RSNISAC] GBT] Guantiy | Rate ]per] — Amount\nfo Fate\n1 |Portiand Cement 3%| 280] 6,000.00| ] 16,90,900.001\n2 |Ceramic Tiles 8 %|9000 Sft| | 28.00|s9Ft) 840,000.00)\n2520005\nIntegrated Tax| 7,05 600.00\nTaal 32.25 600.00)\naunt Charges Gr ver EaOE\nINR Thirty Two Lakh Twenty Five Thousand Six Hundred Only\narable [_
# ...

# %%
text = extract_text
text = text.split('\n')
text
# Out:
# ['Tax Invoice',
#  '(SUPPLY MEANT FOR EXPORTISUPPLY To SEZ UNIT OR SEZ DEVELOPER FOR AUTHORISED OPERATIONS ON PAYMENT OF GST)',
#  '',
#  'National Enterprises invoice No, (Dated',
#  '/Bommanahali, Bangab 47 5.Jul 2017',
#  'GSTINUIN: 29) zi Datvany Note IModerTerms of Payment',
#  'State Name ; Kamataka, Code : 29 DNe1 3 Installments',
#  'Suppers Re [Other Reference',
#  'a7',
#  'Borer Buyers Order No ated',
#  'SSH Enterprises - Dhaka /SR/199 1.Jul.2017',
#  'Dhanmondi, Dhaka Despatch Document Na Delivery Nofe Dae',
#  'poci271 5.Jul 2017',
#  'Despatcned through Destination',
#  '‘Cargo Flight Dhaka',
#  'Bil of Laing ERR NB wotor VOnETE ND,',
#  '12121 at. S.Jul.2017_|6e771111',
#  '',
#  '(Courity Bangladesh',
#  '',
#  'Fromme o Delvey',
#  'iy Description of Goods RSNISAC] GBT] Guantiy | Rate ]per] — Amount',
#  'fo Fate',
#  '1 |Portiand Cement 3%| 280] 6,000.00| ] 16,90,900.001',
#  '2 |Ceramic Tiles 8 %|9000 Sft| | 28.00|s9Ft) 840,000.00)',
#  '2520005',
# ...

# %% [markdown]
# ---
